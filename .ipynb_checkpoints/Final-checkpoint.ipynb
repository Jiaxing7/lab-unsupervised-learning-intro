# %%
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D

# %%
df = pd.read_csv('../data/total.csv')
df['song'] = df['song'].str.lower()
df=df.drop_duplicates(subset='id')
df
# Out:
#                                                     song            artist  \
# 0                                             sure thing            Miguel
# 1                                                  adorn            Miguel
# 2                        girl with the tattoo enter.lewd            Miguel
# 3                                                 coffee            Miguel
# 4                              power trip (feat. miguel)           J. Cole
# ...                                                  ...               ...
# 10052                           sweetened clouds of blue   Sa'hayla Harden
# 10053                                         alb lebnen     Cynthya Karam
# 10054                           festa linda: set, vol. 1      DJ Malokinha
# 10055  escape (originally performed by deadmau5, kask...  Backing Business
# 10056                                    cantos costeños      Hayla Monpie
#
#                                               album_name  \
# 0                                      All I Want Is You
# 1                                     Kaleidoscope Dream
# 2                                      All I Want Is You
# 3                             Wildheart (Deluxe Version)
# 4                           Born Sinner (Deluxe Version)
# ...                                                  ...
# 10052                                              Toitū
# 10053                                         Alb Lebnen
# 10054                           Festa Linda: Set, Vol. 1
# 10055                          Pristine Karaoke, Vol. 73
# 10056  Tocando Tierra (A Tribute to Latin American Mu...
#
#                      album_id  danceability  energy   key  loudness  mode  \
# 0      493HYe7N5pleudEZRyhE7R         0.684   0.607  11.0    -8.127   0.0
# 1      21XMv0TCsnhWPt7MNVvkzD         0.625   0.576  11.0    -5.693   0.0
# 2      493HYe7N5pleudEZRyhE7R         0.372   0.239   6.0   -11.314   0.0
# 3      6W8ZsoinSMViZMh9aYK7gQ         0.556   0.618  10.0    -7.471   0.0
# 4      5FP9keIJnlSCKnkdVOf623         0.667   0.608   1.0    -7.054   1.0
# ...                       ...           ...     ...   ...       ...   ...
# 10052  3ujQkC5z4Z2lqydx6vXd3E         0.696   0.587   6.0    -6.717   0.0
# 10053  16iFs8umImAKrVIh6LXFDI         0.379   0.662   7.0    -4.791   1.0
# 10054  7zzEM1LUJEybyY6BXLbKMT         0.845   0.700   6.0    -7.150   0.0
# 10055  6hss3dBDQeyQnvDt2rwMRb         0.671   0.694   9.0    -9.650   0.0
# 10056  69fTs5KxME0WBibAXYHTh3         0.543   0.351   2.0   -15.202   1.0
#
#        speechiness  ...  liveness  valence    tempo                      id  \
# 0           0.1000  ...    0.1910    0.498   81.001  0JXXNGljqupsJaZsgSbMZV
# 1           0.1750  ...    0.1870    0.235  179.063  25cUhiAod71TIQSNicOaW3
# 2           0.0296  ...    0.1680    0.127  113.451  1eUGmzzvahJjOSWgDHuRlv
# 3           0.0463  ...    0.1530    0.121   80.985  6vMpPxLV0F5Diwcs6awI1Z
# 4           0.2160  ...    0.4260    0.475   99.992  2uwnP6tZVVmTovzX5ELooy
# ...            ...  ...       ...      ...      ...                     ...
# 10052       0.0275  ...    0.1290    0.691   93.016  6voHCkaqVh2tXMFh6eqqCn
# 10053       0.0388  ...    0.2420    0.207   80.440  4zQjeNqyX0Oltg0Ys3PdD9
# 10054       0.1650  ...    0.2890    0.745  103.043  4mdSCaFdE3jYDs4KLb0uJk
# 10055       0.0399  ...    0.0558    0.400  126.015  0ENPdsvNUJT8syYBghaUQc
# 10056       0.1550  ...    0.4250    0.751   99.885  4XyoArEtZykHbiJ2rvv5EO
#
#                                         uri  \
# 0      spotify:track:0JXXNGljqupsJaZsgSbMZV
# 1      spotify:track:25cUhiAod71TIQSNicOaW3
# 2      spotify:track:1eUGmzzvahJjOSWgDHuRlv
# 3      spotify:track:6vMpPxLV0F5Diwcs6awI1Z
# 4      spotify:track:2uwnP6tZVVmTovzX5ELooy
# ...                                     ...
# 10052  spotify:track:6voHCkaqVh2tXMFh6eqqCn
# 10053  spotify:track:4zQjeNqyX0Oltg0Ys3PdD9
# 10054  spotify:track:4mdSCaFdE3jYDs4KLb0uJk
# 10055  spotify:track:0ENPdsvNUJT8syYBghaUQc
# 10056  spotify:track:4XyoArEtZykHbiJ2rvv5EO
#
#                                               track_href time_signature  \
# 0      https://api.spotify.com/v1/tracks/0JXXNGljqups...            4.0
# 1      https://api.spotify.com/v1/tracks/25cUhiAod71T...            4.0
# 2      https://api.spotify.com/v1/tracks/1eUGmzzvahJj...            4.0
# 3      https://api.spotify.com/v1/tracks/6vMpPxLV0F5D...            4.0
# 4      https://api.spotify.com/v1/tracks/2uwnP6tZVVmT...            4.0
# ...                                                  ...            ...
# 10052  https://api.spotify.com/v1/tracks/6voHCkaqVh2t...            4.0
# 10053  https://api.spotify.com/v1/tracks/4zQjeNqyX0Ol...            4.0
# 10054  https://api.spotify.com/v1/tracks/4mdSCaFdE3jY...            4.0
# 10055  https://api.spotify.com/v1/tracks/0ENPdsvNUJT8...            4.0
# 10056  https://api.spotify.com/v1/tracks/4XyoArEtZykH...            4.0
#
#       duration_ms  explicit  popularity
# 0        195373.0     False          91
# 1        193147.0     False          69
# 2        102813.0     False          81
# 3        286573.0      True          60
# 4        241160.0      True          77
# ...           ...       ...         ...
# 10052    218548.0     False           0
# 10053    290000.0     False           0
# 10054    423577.0     False          16
# 10055    230388.0     False           0
# 10056    277053.0     False           0
#
# [9121 rows x 22 columns]

# %%
X = df.select_dtypes(np.number)

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state=1)
kmeans.fit(X)
# Out:
# KMeans(random_state=1)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    2036
# 1    1861
# 2     340
# 3      31
# 4       5
# 5    3262
# 6     972
# 7     614
# dtype: int64

# %%
scaler = StandardScaler()

# %% [markdown]
# # get songlist from PopVortex Hot 100

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)
response.status_code 
soup = BeautifulSoup(response.content, "html.parser")

# %%
title = []
singer = []

num_iter = len(soup.select("div.chart-content.col-xs-12.col-sm-8"))

for i in range(num_iter):
    title.append(soup.select("p.title-artist cite.title")[i].get_text())
    singer.append(soup.select("p > em")[i].get_text())

df1 = pd.DataFrame({"song":title,"artist":singer})
df1['song'] = df1['song'].str.lower()
df1
# Out:
#                                  song                      artist
# 0                        need a favor                  Jelly Roll
# 1                  heart like a truck               Lainey Wilson
# 2                     son of a sinner                  Jelly Roll
# 3                          last night               Morgan Wallen
# 4                           thank god  Kane Brown & Katelyn Brown
# ..                                ...                         ...
# 95  all of the girls you loved before                Taylor Swift
# 96                    this is our god                Phil Wickham
# 97                             mother              Meghan Trainor
# 98                      hate my heart            Carrie Underwood
# 99                               lost                 LINKIN PARK
#
# [100 rows x 2 columns]

# %% [markdown]
# # recommender

# %%
song = input("Please enter a song title: ").lower()

if song in df1['song'].values:
    recommendation = df1[df1['song'] != song].sample()
    recommended_song = recommendation.iloc[0]['song']
    recommended_artist = recommendation.iloc[0]['artist']
    print(f"It's from PopVortex Hot 100 list.")
    print(f"Here's anothor recommendation for you: {recommended_song} by {recommended_artist}")
else:
    if song in df['song'].values:
        pick=pd.DataFrame(df[df['song']==song].iloc[0]).T
        pick=pick[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
         'instrumentalness', 'liveness', 'valence', 'tempo','time_signature', 'duration_ms', 'popularity']]
        pick=pick.apply(pd.to_numeric, errors='coerce')
    
        new_song_prep = StandardScaler().fit_transform(pick)
        new_song_cluster = kmeans.predict(new_song_prep)[0]
        similar_songs = df[clusters == new_song_cluster]
        if len(similar_songs)>0:
            recommendations = similar_songs.sample()
            print(f"Here's a recommendation for you: {list(recommendations['song'])[0]} by {list(recommendations['artist'])[0]}")
        else:
            print("Sorry, we don't have a recommendation at this time.")   
    else:
        print("Sorry, we don't have a recommendation at this time.")
# Out:
# Please enter a song title: lost
# It's from PopVortex Hot 100 list.
# Here's anothor recommendation for you: you oughta know by Alanis Morissette

# %% [markdown]
# ### Update, only part of the song name needs to be entered

# %%
song = input("Please enter a song title: ").lower()
song = df[df['song'].str.contains(song)]
if len(song)>0:
    song = list(song['song'])[0]
    if song in df1['song'].values:
        recommendation = df1[df1['song'] != song].sample()
        recommended_song = recommendation.iloc[0]['song']
        recommended_artist = recommendation.iloc[0]['artist']
        print(f"It's from PopVortex Hot 100 list.")
        print(f"Here's anothor recommendation for you: {recommended_song} by {recommended_artist}")
    else:
        if song in df['song'].values:
            pick=pd.DataFrame(df[df['song']==song].iloc[0]).T
            pick=pick[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
             'instrumentalness', 'liveness', 'valence', 'tempo','time_signature', 'duration_ms', 'popularity']]
            pick=pick.apply(pd.to_numeric, errors='coerce')
    
            new_song_prep = StandardScaler().fit_transform(pick)
            new_song_cluster = kmeans.predict(new_song_prep)[0]
            similar_songs = df[clusters == new_song_cluster]
            if len(similar_songs)>0:
                recommendations = similar_songs.sample()
                print(f"Here's a recommendation for you: {list(recommendations['song'])[0]} by {list(recommendations['artist'])[0]}")
            else:
                print("Sorry, we don't have a recommendation at this time.")   
        else:
            print("Sorry, we don't have a recommendation at this time.")
else:
    print("Sorry, we don't have a recommendation at this time.")
# Out:
# Please enter a song title: flowe
# Here's a recommendation for you: ways to go - ringtone tribute to grouplove by 2013 Ringtone Legends
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
